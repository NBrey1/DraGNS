# %%
import sys
# !pip install ase
import os
import numpy as np
import subprocess
import time
import sys
from IPython.display import clear_output

# Simulation Configuration
# We use a 3x3x2 supercell (216 atoms) which is the standard minimum size
# for accurate ice simulations on personal computing hardware.
cp2k_executable = "cp2k.ssmp"
xyz_filename = "ice_d20.xyz"
input_filename = "ice_d20.inp"
output_filename = "ice_d20.out"

print("[STATUS] Configuration loaded.")
print(f"[STATUS] Executable: {cp2k_executable}")
print(f"[STATUS] Input/Output: {input_filename} / {output_filename}")
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# [STATUS] Configuration loaded.
# [STATUS] Executable: cp2k.ssmp
# [STATUS] Input/Output: ice_d20.inp / ice_d20.out

# %%
pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.6 MB/s  0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Not uninstalling pip at /opt/homebrew/lib/python3.14/site-packages, outside environment /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec
#     Can't uninstall 'pip'. No files were found to uninstall.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# Configuration
xyz_filename = "ice_d20.xyz"

def generate_small_ice_structure(filename):
    print("[STATUS] Generating minimal 2x2x2 Ice Ih Supercell...")
    
    # Lattice Constants (Angstroms) from your data
    a = 4.518
    c = 7.356
    
    # REDUCED DIMENSIONS (2x2x2)
    # This creates 32 molecules (96 atoms) instead of 72 molecules (216 atoms)
    # For the 216 atoms, modify this to 3,3,2
    nx, ny, nz = 2, 2, 2 
    
    # Fractional coordinates for Wurtzite/Ice Ih
    frac_coords = np.array([
        [1/3, 2/3, 1/16], 
        [2/3, 1/3, 5/16], 
        [1/3, 2/3, 9/16], 
        [2/3, 1/3, 13/16]
    ])

    atoms = []
    
    for ix in range(nx):
        for iy in range(ny):
            for iz in range(nz):
                for frac in frac_coords:
                    f_shift = frac + np.array([ix, iy, iz])
                    
                    # Convert to Cartesian
                    x = a * (f_shift[0] + f_shift[1] * np.cos(np.radians(120)))
                    y = a * f_shift[1] * np.sin(np.radians(120))
                    z = c * f_shift[2]
                    
                    # Add Atoms
                    atoms.append(f"O {x:.4f} {y:.4f} {z:.4f}")
                    atoms.append(f"H {x+0.757:.4f} {y:.4f} {z:.4f}")
                    atoms.append(f"H {x-0.379:.4f} {y+0.656:.4f} {z:.4f}")

    # Write to XYZ file
    with open(filename, "w") as f:
        f.write(f"{len(atoms)}\n")
        #modify for the 216 run
        f.write("Ice Ih 2x2x2 Supercell \n")
        f.write("\n".join(atoms))
        
    print(f"[SUCCESS] Structure saved to '{filename}'.")
    print(f"[INFO] Atom count reduced to: {len(atoms)}")
    
    # Return new box dimensions for the input file
    return a * nx, a * ny, c * nz

# Generate and capture new box size

box_a, box_b, box_c = generate_small_ice_structure(xyz_filename)

#change these for the upcoming step if running 216
print(f"NEW BOX DIMENSIONS: A={box_a:.3f}, B={box_b:.3f}, C={box_c:.3f}")
# Out:
# [STATUS] Generating minimal 2x2x2 Ice Ih Supercell...
# [SUCCESS] Structure saved to 'ice_d20.xyz'.
# [INFO] Atom count reduced to: 96
# NEW BOX DIMENSIONS: A=9.036, B=9.036, C=14.712

# %%
input_filename = "ice_d20.inp"
 #change name of Project for 216 to not overwrite work 

cp2k_content = f"""&GLOBAL
  PROJECT Ice_Ih_Small
  RUN_TYPE GEO_OPT
  PRINT_LEVEL LOW
&END GLOBAL

&FORCE_EVAL
  METHOD Quickstep
  &DFT
    &QS
      METHOD PM6
      EPS_DEFAULT 1.0E-10
    &END QS
    &SCF
      MAX_SCF 200
      EPS_SCF 1.0E-4    ! Looser for the bigger molecules, change to 1.0E-5 for smaller runs
      IGNORE_CONVERGENCE_FAILURE .TRUE.
      &OT
        MINIMIZER DIIS
        PRECONDITIONER FULL_SINGLE_INVERSE
      &END OT
    &END SCF
  &END DFT

  &SUBSYS
    &CELL
      ! Updated dimensions for 2x2x2 box
      ABC {box_a:.3f} {box_b:.3f} {box_c:.3f}
      ALPHA_BETA_GAMMA 90 90 120
      PERIODIC XYZ
    &END CELL
    &TOPOLOGY
      COORD_FILE_NAME {xyz_filename}
      COORD_FILE_FORMAT XYZ
    &END TOPOLOGY
  &END SUBSYS
&END FORCE_EVAL

&MOTION
  &GEO_OPT
    MAX_ITER 100
    OPTIMIZER BFGS
  &END GEO_OPT
&END MOTION
"""

with open(input_filename, "w") as f:
    f.write(cp2k_content)

print(f"[STATUS] Input file updated for smaller system: {input_filename}")
# Out:
# [STATUS] Input file updated for smaller system: ice_d20.inp

# %%
print("[STATUS] Starting CP2K Simulation")
start_time = time.time()

# Initialize process
process = subprocess.Popen(
    [cp2k_executable, "-i", input_filename],
    stdout=open(output_filename, "w"),
    stderr=subprocess.STDOUT
)

try:
    # Monitor the output file
    with open(output_filename, "r") as monitor:
        monitor.seek(0, 2) # Jump to end of file
        
        while process.poll() is None:
            line = monitor.readline()
            if not line:
                time.sleep(0.5)
                continue
            
            # Parse SCF steps (Electronic Optimization)
            if "OT DIIS" in line:
                try:
                    parts = line.split()
                    step = int(parts[0])
                    elapsed = int(time.time() - start_time)
                    
                    # Update status display
                    clear_output(wait=True)
                    print(f"[RUNNING] Geometry Optimization")
                    print(f"Elapsed Time: {elapsed} seconds")
                    print(f"Current SCF Step: {step}")
                except ValueError:
                    pass
            
            # Check for Geometry Optimization steps (Structural Relaxation)
            if "GEOMETRY OPTIMIZATION STEP" in line:
                print("[INFO] Geometry Step Converged. Proceeding to next configuration.")

    # Final Status
    if process.returncode == 0:
        total_time = int(time.time() - start_time)
        print(f"\n[SUCCESS] Simulation completed in {total_time} seconds.")
        print(f"[INFO] Results saved to: {output_filename}")
    else:
        print("\n[FAILURE] Simulation exited with errors. Check output file.")

except KeyboardInterrupt:
    process.terminate()
    print("\n[STOPPED] Process terminated by user.")
# Out:
# [RUNNING] Geometry Optimization
# Elapsed Time: 714 seconds
# Current SCF Step: 16
#
# [SUCCESS] Simulation completed in 716 seconds.
# [INFO] Results saved to: ice_d20.out

# %%
import os
import ase.io
import shutil

# Configuration
# This matches the PROJECT name defined in the optimization input

opt_trajectory_file = "Ice_96D20.xyz"

# This matches the COORD_FILE_NAME defined in the optimization input

opt_input_file = "ice_d20.xyz" 
final_coords_file = "ice_d20relaxed.xyz"

print("[STATUS] Locating geometry files...")

if os.path.exists(opt_trajectory_file):
    print(f"[INFO] Trajectory file found: {opt_trajectory_file}")
    try:
        # Read all frames and select the last one (-1)
        frames = ase.io.read(opt_trajectory_file, index=':')
        last_frame = frames[-1]
        
        # Save the relaxed structure
        ase.io.write(final_coords_file, last_frame)
        print(f"[SUCCESS] Extracted relaxed geometry from Step {len(frames)}.")
        
    except Exception as e:
        print(f"[ERROR] Failed to read trajectory: {e}")
        print("[ACTION] Reverting to unoptimized structure as fallback.")
        shutil.copy(opt_input_file, final_coords_file)

elif os.path.exists(opt_input_file):
    print("[WARNING] Optimization trajectory not found (Simulation may have been too fast to write it).")
    print("[ACTION] Using initial input structure.")
    shutil.copy(opt_input_file, final_coords_file)
    
else:
    print("[ERROR] No structure files found. Please ensure the optimization step ran successfully.")

print(f"[INFO] Coordinate file ready: {final_coords_file}")
# Out:
# [STATUS] Locating geometry files...
# [WARNING] Optimization trajectory not found (Simulation may have been too fast to write it).
# [ACTION] Using initial input structure.
# [INFO] Coordinate file ready: ice_d20relaxed.xyz

# %%
import os

md_input_filename = "ice_d2o_96.inp"
md_output_filename = "ice_d2o_96.out"
start_coords_file = "ice_d20relaxed.xyz"

if not os.path.exists(start_coords_file):
    start_coords_file = "ice_d20.xyz"

if not os.path.exists(start_coords_file):
    print(f"[ERROR] CRITICAL: Coordinates not found!")
else:
    md_content = f"""&GLOBAL
      PROJECT Titan_Ice_D2O_96
      RUN_TYPE MD
      PRINT_LEVEL LOW
    &END GLOBAL

    &FORCE_EVAL
      METHOD Quickstep
      &DFT
        &QS
          METHOD PM6
          EPS_DEFAULT 1.0E-10
        &END QS
        &SCF
          MAX_SCF 30                  
          EPS_SCF 1.0E-5  ! LOOSENED: Speeds up each step significantly
          IGNORE_CONVERGENCE_FAILURE .TRUE.
          &OT
            MINIMIZER DIIS
            PRECONDITIONER FULL_SINGLE_INVERSE
          &END OT
        &END SCF
      &END DFT

      &SUBSYS
        &CELL
          ABC 9.036 9.036 14.712
          ALPHA_BETA_GAMMA 90 90 120
          PERIODIC XYZ
        &END CELL
        &TOPOLOGY
          COORD_FILE_NAME {start_coords_file}
          COORD_FILE_FORMAT XYZ
        &END TOPOLOGY

        &KIND H
          ELEMENT H
          MASS 2.014102   
        &END KIND
      &END SUBSYS
    &END FORCE_EVAL

    &MOTION
      &MD
        ENSEMBLE NVE  
        STEPS 500     ! REDUCED: Half the total time, blurrier graph but way faster
        TIMESTEP 1.0  
        TEMPERATURE 94.0
      &END MD
      &PRINT
        &TRAJECTORY
          &EACH
            MD 1  
          &END EACH
        &END TRAJECTORY
        &VELOCITIES   
          &EACH
            MD 1
          &END EACH
        &END VELOCITIES
      &END PRINT
    &END MOTION
    """

    with open(md_input_filename, "w") as f:
        f.write(md_content)

    print(f"[STATUS] Ready to run SPEEDRUN D2O Simulation: {md_input_filename}")
# Out:
# [STATUS] Ready to run SPEEDRUN D2O Simulation: ice_d2o_96.inp

# %%
import subprocess
import time
from IPython.display import clear_output

cp2k_executable = "cp2k.ssmp"
md_input = md_input_filename    
md_output = md_output_filename

# --- NEW: Dynamically grab target_steps from the input file ---
target_steps = 1000  # Fallback
try:
    with open(md_input, "r") as f:
        for line in f:
            # Look for the STEPS keyword in the input
            if "STEPS" in line.upper() and not "MAX_SCF" in line.upper():
                target_steps = int(line.split()[1])
                break
except Exception as e:
    print(f"[WARNING] Could not read steps from input, defaulting to {target_steps}")

print(f"[STATUS] Initializing D2O (96 Atoms) Simulation for {target_steps} steps...")
start_time = time.time()

# Standard run command for laptop
process = subprocess.Popen(
    [cp2k_executable, "-i", md_input],
    stdout=open(md_output, "w"),
    stderr=subprocess.STDOUT
)

try:
    with open(md_output, "r") as monitor:
        while process.poll() is None:
            line = monitor.readline()
            if not line:
                time.sleep(0.5)
                continue
            
            # CP2K prints step number like " STEP NUMBER                      1"
            if "STEP NUMBER" in line.upper():
                try:
                    step = int(line.split()[-1])
                    elapsed = int(time.time() - start_time)
                    if step > 0:
                        percent = (step / target_steps) * 100
                        clear_output(wait=True)
                        print(f"[RUNNING] Titan D2O Ice MD (96 atoms)")
                        print(f"Step: {step} / {target_steps} ({percent:.1f}%)")
                        print(f"Time Elapsed: {elapsed}s")
                except: pass

    # Catch the final return code
    if process.returncode == 0:
        clear_output(wait=True)
        print(f"[SUCCESS] Simulation Finished in {int(time.time() - start_time)}s!")
    else:
        print("\n[FAILURE] Simulation exited with error code. Check the .out file.")

except KeyboardInterrupt:
    process.terminate()
    print("\n[STOPPED] User cancelled.")
# Out:
# [SUCCESS] Simulation Finished in 2980s!

# %%
import numpy as np
import matplotlib.pyplot as plt
import ase.io
from scipy.signal.windows import blackman

# --- CONFIGURATION ---
velocity_file = "Titan_Ice_D2O_96-vel-1.xyz"  # Update this to your CP2K velocity output file!
dt_fs = 1.0                                  # Timestep in femtoseconds (from your CP2K input)
c_cm_s = 2.9979e10                           # Speed of light in cm/s

print(f"Reading velocities from {velocity_file}...")

# 1. Read the trajectory (CP2K writes velocities into the "positions" block of a .xyz file)
# ase.io will load them as coordinates, but we know they are actually velocities (Bohr/au_time or Angstrom/fs)
# Note: As long as the units are consistent, the FFT frequencies will be correct.
traj = ase.io.read(velocity_file, index=":")
n_frames = len(traj)
n_atoms = len(traj[0])

# Extract velocities into a numpy array: shape (n_frames, n_atoms, 3)
velocities = np.array([atoms.positions for atoms in traj])

print(f"Loaded {n_frames} frames for {n_atoms} atoms.")

# 2. Calculate the Power Spectrum (VDOS) via FFT
# Apply a window function (Blackman) to smooth the spectrum and reduce FFT noise
window = blackman(n_frames)
window = window[:, np.newaxis, np.newaxis] # Reshape to broadcast across atoms and 3D coords

# Multiply velocities by the window
v_windowed = velocities * window

# Perform Real Fast Fourier Transform along the time axis (axis 0)
v_fft = np.fft.rfft(v_windowed, axis=0)

# Power spectrum: |FFT|^2, sum over X,Y,Z (axis 2), and average over all atoms (axis 1)
dos = np.mean(np.sum(np.abs(v_fft)**2, axis=2), axis=1)

# 3. Calculate Frequencies in cm^-1
# dt in seconds
dt_s = dt_fs * 1e-15 
# Get frequencies in Hz
freqs_hz = np.fft.rfftfreq(n_frames, d=dt_s)
# Convert Hz to Wavenumber (cm^-1)
wavenumbers = freqs_hz / c_cm_s

# Normalize DOS for easier plotting
dos = dos / np.max(dos)
max_dos = 1.0

# --- 4. PLOTTING ---
plt.figure(figsize=(12, 6))
plt.plot(wavenumbers, dos, color='black', linewidth=1.5)

# --- Highlight Physics Regions for D2O ---
# Lattice / Translation (< 350)
plt.axvspan(0, 350, color='blue', alpha=0.1)
plt.text(175, max_dos * 0.8, "Lattice", color='blue', ha='center', fontsize=11, fontweight='bold')

# Libration (350 - 1000)
plt.axvspan(350, 1000, color='green', alpha=0.1)
plt.text(675, max_dos * 0.6, "Libration", color='green', ha='center', fontsize=11, fontweight='bold')

# Bending (~1200)
plt.axvspan(1100, 1300, color='orange', alpha=0.1)
plt.text(1200, max_dos * 0.4, "Bending", color='darkorange', ha='center', fontsize=11, fontweight='bold')

# Stretching (~2300-2600)
plt.axvspan(2300, 2600, color='red', alpha=0.1)
plt.text(2450, max_dos * 0.4, "Stretching", color='red', ha='center', fontsize=11, fontweight='bold')

# Styling
plt.title('Vibrational Density of States - D₂O (CP2K PM6 NVE)', fontsize=14, fontweight='bold')
plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=12)
plt.ylabel('Density of States (Normalized)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)

# Set X-limit to match your physics regions
plt.xlim(0, 3000) 
plt.ylim(0, max_dos * 1.1)

# Fill the curve slightly for aesthetics
plt.fill_between(wavenumbers, dos, color='gray', alpha=0.3)

plt.savefig("heavy_ice_cp2k_2_2.jpg")
plt.tight_layout()
plt.show()
# Out:
# Reading velocities from Titan_Ice_D2O_96-vel-1.xyz...
# Loaded 501 frames for 96 atoms.

# %%
import nglview as nv
import ase.io

# 1. Load the trajectory (list of atoms)
trajectory = ase.io.read("Titan_Ice_D2O_96-pos-1.xyz", index=":")

# 2. Wrap it in the NGLView trajectory adapter
t = nv.ASETrajectory(trajectory)

# 3. Create the player
view = nv.NGLWidget(t)
view.add_unitcell()
view
# Out:
# NGLWidget(max_frame=500)

# %%
import os

md_input_filename = "ice_d2o_96.inp"
md_output_filename = "ice_d2o_96.out"
start_coords_file = "ice_d20relaxed.xyz"

if not os.path.exists(start_coords_file):
    start_coords_file = "ice_d20.xyz"

if not os.path.exists(start_coords_file):
    print(f"[ERROR] CRITICAL: Coordinates not found!")
else:
    md_content = f"""&GLOBAL
      PROJECT Titan_Ice_D2O_Quantum
      RUN_TYPE MD
      PRINT_LEVEL LOW
    &END GLOBAL

    &FORCE_EVAL
      METHOD Quickstep
      &DFT
        &QS
          METHOD PM6
          EPS_DEFAULT 1.0E-10
        &END QS
        &SCF
          MAX_SCF 40                  
          EPS_SCF 1.0E-5  ! Optimized for faster step calculation
          IGNORE_CONVERGENCE_FAILURE .TRUE.
          &OT
            MINIMIZER DIIS
            PRECONDITIONER FULL_SINGLE_INVERSE
          &END OT
        &END SCF
      &END DFT

      &SUBSYS
        &CELL
          ABC 9.036 9.036 14.712
          ALPHA_BETA_GAMMA 90 90 120
          PERIODIC XYZ
        &END CELL
        &TOPOLOGY
          COORD_FILE_NAME {start_coords_file}
          COORD_FILE_FORMAT XYZ
        &END TOPOLOGY

        &KIND H
          ELEMENT H
          MASS 2.014102   ! Heavy water
        &END KIND
      &END SUBSYS
    &END FORCE_EVAL

    &MOTION
      &MD
        ENSEMBLE NVE  
        STEPS 1000    ! 1000 steps at 1.0 fs = 1 picosecond total
        TIMESTEP 1.0  
        TEMPERATURE 94.0
      &END MD
      &PRINT
        &TRAJECTORY
          &EACH
            MD 1  
          &END EACH
        &END TRAJECTORY
        &VELOCITIES   
          &EACH
            MD 1
          &END EACH
        &END VELOCITIES
      &END PRINT
    &END MOTION
    """

    with open(md_input_filename, "w") as f:
        f.write(md_content)

    print(f"[STATUS] Ready to run OPTIMIZED QUANTUM Simulation: {md_input_filename}")
# Out:
# [STATUS] Ready to run OPTIMIZED QUANTUM Simulation: ice_d2o_96.inp

# %%
import subprocess
import time
from IPython.display import clear_output

cp2k_executable = "cp2k.ssmp"
md_input = md_input_filename    
md_output = md_output_filename

# --- NEW: Dynamically grab target_steps from the input file ---
target_steps = 1000  # Fallback
try:
    with open(md_input, "r") as f:
        for line in f:
            # Look for the STEPS keyword in the input
            if "STEPS" in line.upper() and not "MAX_SCF" in line.upper():
                target_steps = int(line.split()[1])
                break
except Exception as e:
    print(f"[WARNING] Could not read steps from input, defaulting to {target_steps}")

print(f"[STATUS] Initializing D2O (96 Atoms) Simulation for {target_steps} steps...")
start_time = time.time()

# Standard run command for laptop
process = subprocess.Popen(
    [cp2k_executable, "-i", md_input],
    stdout=open(md_output, "w"),
    stderr=subprocess.STDOUT
)

try:
    with open(md_output, "r") as monitor:
        while process.poll() is None:
            line = monitor.readline()
            if not line:
                time.sleep(0.5)
                continue
            
            # CP2K prints step number like " STEP NUMBER                      1"
            if "STEP NUMBER" in line.upper():
                try:
                    step = int(line.split()[-1])
                    elapsed = int(time.time() - start_time)
                    if step > 0:
                        percent = (step / target_steps) * 100
                        clear_output(wait=True)
                        print(f"[RUNNING] Titan D2O Ice MD (96 atoms)")
                        print(f"Step: {step} / {target_steps} ({percent:.1f}%)")
                        print(f"Time Elapsed: {elapsed}s")
                except: pass

    # Catch the final return code
    if process.returncode == 0:
        clear_output(wait=True)
        print(f"[SUCCESS] Simulation Finished in {int(time.time() - start_time)}s!")
    else:
        print("\n[FAILURE] Simulation exited with error code. Check the .out file.")

except KeyboardInterrupt:
    process.terminate()
    print("\n[STOPPED] User cancelled.")
# Out:
# [SUCCESS] Simulation Finished in 7032s!

# %%
import numpy as np
import matplotlib.pyplot as plt
import ase.io
from scipy.signal.windows import blackman

# --- CONFIGURATION ---
velocity_file = "Titan_Ice_D2O_Quantum-vel-1.xyz"  
dt_fs = 1.0
c_cm_s = 2.9979e10                           # Speed of light in cm/s

print(f"Reading velocities from {velocity_file}...")

# 1. Read the trajectory (CP2K writes velocities into the "positions" block of a .xyz file)
# ase.io will load them as coordinates, but we know they are actually velocities (Bohr/au_time or Angstrom/fs)
# Note: As long as the units are consistent, the FFT frequencies will be correct.
traj = ase.io.read(velocity_file, index=":")
n_frames = len(traj)
n_atoms = len(traj[0])

# Extract velocities into a numpy array: shape (n_frames, n_atoms, 3)
velocities = np.array([atoms.positions for atoms in traj])

print(f"Loaded {n_frames} frames for {n_atoms} atoms.")

# 2. Calculate the Power Spectrum (VDOS) via FFT
# Apply a window function (Blackman) to smooth the spectrum and reduce FFT noise
window = blackman(n_frames)
window = window[:, np.newaxis, np.newaxis] # Reshape to broadcast across atoms and 3D coords

# Multiply velocities by the window
v_windowed = velocities * window

# Perform Real Fast Fourier Transform along the time axis (axis 0)
v_fft = np.fft.rfft(v_windowed, axis=0)

# Power spectrum: |FFT|^2, sum over X,Y,Z (axis 2), and average over all atoms (axis 1)
dos = np.mean(np.sum(np.abs(v_fft)**2, axis=2), axis=1)

# 3. Calculate Frequencies in cm^-1
# dt in seconds
dt_s = dt_fs * 1e-15 
# Get frequencies in Hz
freqs_hz = np.fft.rfftfreq(n_frames, d=dt_s)
# Convert Hz to Wavenumber (cm^-1)
wavenumbers = freqs_hz / c_cm_s

# Normalize DOS for easier plotting
dos = dos / np.max(dos)
max_dos = 1.0

# --- 4. PLOTTING ---
plt.figure(figsize=(12, 6))
plt.plot(wavenumbers, dos, color='black', linewidth=1.5)

# --- Highlight Physics Regions for D2O ---
# Lattice / Translation (< 350)
plt.axvspan(0, 350, color='blue', alpha=0.1)
plt.text(175, max_dos * 0.8, "Lattice", color='blue', ha='center', fontsize=11, fontweight='bold')

# Libration (350 - 1000)
plt.axvspan(350, 1000, color='green', alpha=0.1)
plt.text(675, max_dos * 0.6, "Libration", color='green', ha='center', fontsize=11, fontweight='bold')

# Bending (~1200)
plt.axvspan(1100, 1300, color='orange', alpha=0.1)
plt.text(1200, max_dos * 0.4, "Bending", color='darkorange', ha='center', fontsize=11, fontweight='bold')

# Stretching (~2300-2600)
plt.axvspan(2300, 2600, color='red', alpha=0.1)
plt.text(2450, max_dos * 0.4, "Stretching", color='red', ha='center', fontsize=11, fontweight='bold')

# Styling
plt.title('Vibrational Density of States - D₂O (Looser SCF Covergence)', fontsize=14, fontweight='bold')
plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=12)
plt.ylabel('Density of States (Normalized)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)

# Set X-limit to match your physics regions
plt.xlim(0, 3000) 
plt.ylim(0, max_dos * 1.1)

# Fill the curve slightly for aesthetics
plt.fill_between(wavenumbers, dos, color='gray', alpha=0.3)

plt.savefig("d2o_2_2_optimized.jpg")

plt.tight_layout()
plt.show()
# Out:
# Reading velocities from Titan_Ice_D2O_Quantum-vel-1.xyz...
# Loaded 1001 frames for 96 atoms.
