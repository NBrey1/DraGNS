# %%
# Execute this first 
#
#  * trigger notebook styling
#  * check if notebook had been modified since its distribution
# 
# Note: executing any cells before this modifies the notebook.
# 

import os

# Add Homebrew's bin folder to the system path used by Jupyter
os.environ['PATH'] += ":/opt/homebrew/bin"

# Test if it works now
# !gmx -version

#check_notebook()
# Out:
#                      :-) GROMACS - gmx, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx -version
#
# GROMACS version:     2025.4-Homebrew
# Precision:           mixed
# Memory model:        64 bit
# MPI library:         thread_mpi
# OpenMP support:      enabled (GMX_OPENMP_MAX_THREADS = 128)
# GPU support:         disabled
# SIMD instructions:   ARM_NEON_ASIMD
# CPU FFT library:     fftw-3.3.10
# GPU FFT library:     none
# Multi-GPU FFT:       none
# TNG support:         enabled
# Hwloc support:       disabled
# Tracing support:     disabled
# C compiler:          /opt/homebrew/opt/gcc/bin/gcc-15
# C compiler flags:    -fexcess-precision=fast -funroll-all-loops -Wno-missing-field-initializers -O3 -DNDEBUG
# C++ compiler:        /opt/homebrew/opt/gcc/bin/g++-15
# C++ compiler flags:  -fexcess-precision=fast -funroll-all-loops -Wno-missing-field-initializers -Weverything -Wno-c++98-compat -Wno-c++98-compat-pedantic -Wno-return-std-move-in-c++11 -Wno-source-uses-openmp -Wno-c++17-extensions -Wno-documentation-unknown-command -Wno-covered-switch-default -Wno-switch-enum -Wno-switch-default -Wno-extra-semi-stmt -Wno-weak-vtables -Wno-shadow -Wno-padded -Wno-reserved-id-macro -Wno-double-promotion -Wno-exit-time-destructors -Wno-global-constructors -Wno-documentation -Wno-format-nonliteral -Wno-used-but-marked-unused -Wno-float-equal -Wno-conditional-uninitialized -Wno-conversion -Wno-disabled-macro-expansion -Wno-unused-macros -Wno-unsafe-buffer-usage -Wno-cast-function-type-strict SHELL:-fopenmp -O3 -DNDEBUG
# BLAS library:        External - detected on the system
# LAPACK library:      External - detected on the system

# %%
# %pip install nglview pandas mdtraj numpy matplotlib
import nglview as ng
import pandas as pd
import mdtraj as md
import numpy as np
import matplotlib
# Out:
# Requirement already satisfied: nglview in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (4.0)
# Requirement already satisfied: pandas in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (2.3.3)
# Requirement already satisfied: mdtraj in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (1.11.1)
# Requirement already satisfied: numpy in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (2.2.6)
# Requirement already satisfied: matplotlib in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (3.10.8)
# Requirement already satisfied: ipywidgets>=8 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from nglview) (8.1.8)
# Requirement already satisfied: notebook>=7 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from nglview) (7.5.1)
# Requirement already satisfied: jupyterlab>=3 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from nglview) (4.5.2)
# Requirement already satisfied: jupyterlab_widgets in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from nglview) (3.0.16)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from mdtraj) (1.17.0)
# Requirement already satisfied: pyparsing in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from mdtraj) (3.3.1)
# Requirement already satisfied: packaging in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from mdtraj) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: comm>=0.1.3 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from ipywidgets>=8->nglview) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from ipywidgets>=8->nglview) (9.9.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from ipywidgets>=8->nglview) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from ipywidgets>=8->nglview) (4.0.15)
# Requirement already satisfied: decorator>=4.3.2 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets>=8->nglview) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets>=8->nglview) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets>=8->nglview) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets>=8->nglview) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets>=8->nglview) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets>=8->nglview) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets>=8->nglview) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from ipython>=6.1.0->ipywidgets>=8->nglview) (0.6.3)
# Requirement already satisfied: wcwidth in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8->nglview) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets>=8->nglview) (0.8.5)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyterlab>=3->nglview) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyterlab>=3->nglview) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyterlab>=3->nglview) (7.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyterlab>=3->nglview) (3.1.6)
# Requirement already satisfied: jupyter-core in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyterlab>=3->nglview) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyterlab>=3->nglview) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyterlab>=3->nglview) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyterlab>=3->nglview) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyterlab>=3->nglview) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyterlab>=3->nglview) (80.9.0)
# Requirement already satisfied: tornado>=6.2.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyterlab>=3->nglview) (6.5.4)
# Requirement already satisfied: anyio in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from httpx<1,>=0.25.0->jupyterlab>=3->nglview) (4.12.1)
# Requirement already satisfied: certifi in /opt/homebrew/opt/certifi/lib/python3.14/site-packages (from httpx<1,>=0.25.0->jupyterlab>=3->nglview) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from httpx<1,>=0.25.0->jupyterlab>=3->nglview) (1.0.9)
# Requirement already satisfied: idna in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from httpx<1,>=0.25.0->jupyterlab>=3->nglview) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab>=3->nglview) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (8.8.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.23.1)
# Requirement already satisfied: pyzmq>=24 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (2.0.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (4.26.0)
# Requirement already satisfied: requests>=2.31 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (2.32.5)
# Requirement already satisfied: argon2-cffi-bindings in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (25.1.0)
# Requirement already satisfied: appnope>=0.1.2 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3->nglview) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3->nglview) (1.8.19)
# Requirement already satisfied: nest-asyncio>=1.4 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3->nglview) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=3->nglview) (7.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jinja2>=3.0.3->jupyterlab>=3->nglview) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/homebrew/opt/rpds-py/lib/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyter-core->jupyterlab>=3->nglview) (4.5.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.1.1)
# Requirement already satisfied: fqdn in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.5.1)
# Requirement already satisfied: isoduration in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.1.0)
# Requirement already satisfied: uri-template in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (6.3.0)
# Requirement already satisfied: defusedxml in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.5.1)
# Requirement already satisfied: webencodings in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8->nglview) (0.7.0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->jupyterlab>=3->nglview) (2.6.3)
# Requirement already satisfied: lark>=1.2.2 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=8->nglview) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=8->nglview) (3.0.1)
# Requirement already satisfied: pure_eval in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets>=8->nglview) (0.2.3)
# Requirement already satisfied: cffi>=2.0.0b1 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (2.0.0)
# Requirement already satisfied: pycparser in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from cffi>=2.0.0b1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (2.23)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in /opt/homebrew/Cellar/jupyterlab/4.5.2/libexec/lib/python3.14/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=3->nglview) (1.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %cd ~/cp2k/D2O_ice/GroMACK
# !ls
# Out:
# /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# d2o_ice.gro    em.mdp         nvt.mdp        topol.top
# D2O_Mack.ipynb npt1.mdp       production.mdp

# %%
# Load and view the .pdb or .gro file with the following lines
view = ng.show_structure_file("d2o_ice.gro")
view
# Out:
# NGLWidget()

# %%
# Create a single D2O molecule file for GROMACS to copy
with open("single_d2o.gro", "w") as f:
    f.write("Single D2O Molecule Template\n")  # Title
    f.write("4\n")                             # Number of atoms (OW, DW1, DW2, MW)
    f.write("    1ICE     OW    1   1.694   0.176   2.149\n")
    f.write("    1ICE    DW1    2   1.697   0.271   2.145\n")
    f.write("    1ICE    DW2    3   1.740   0.147   2.070\n")
    f.write("    1ICE     MW    4   1.700   0.184   2.138\n")
    # The box size (placeholder)
    f.write("   2.80000   2.80000   2.80000\n")

print("Created 'single_d2o.gro'.")
# Out:
# Created 'single_d2o.gro'.

# %%
# Add the Deuterium Ice Molecules to the larger box
# !gmx insert-molecules -f box.gro -ci single_d2o.gro -nmol 200 -o d2o_solvated.gro -seed 12345 -try 10000
# Out:
#             :-) GROMACS - gmx insert-molecules, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx insert-molecules -f box.gro -ci single_d2o.gro -nmol 200 -o d2o_solvated.gro -seed 12345 -try 10000
#
# Reading solute configuration
# Initialising inter-atomic distances...
#
# WARNING: Masses and atomic (Van der Waals) radii will be guessed
#          based on residue and atom names, since they could not be
#          definitively assigned from the information in your input
#          files. These guessed numbers might deviate from the mass
#          and radius of the atom type. Please check the output
#          files if necessary. Note, that this functionality may
#          be removed in a future GROMACS version. Please, consider
#          using another file format for your input.
#
# NOTE: From version 5.0 gmx insert-molecules uses the Van der Waals radii
# from the source below. This means the results may be different
# compared to previous GROMACS versions.
#
# ++++ PLEASE READ AND CITE THE FOLLOWING REFERENCE ++++
# A. Bondi
# van der Waals Volumes and Radii
# J. Phys. Chem. (1964)
# DOI: 10.1021/j100785a001
# -------- -------- --- Thank You --- -------- --------
#
# Using random seed 12345
# Try 1 success (now 1732 atoms)!
# Try 3 success (now 1736 atoms)!
# Try 6 success (now 1740 atoms)!
# Try 13 success (now 1744 atoms)!
# Try 15 success (now 1748 atoms)!
# Try 22 success (now 1752 atoms)!
# Try 25 success (now 1756 atoms)!
# Try 32 success (now 1760 atoms)!
# Try 35 success (now 1764 atoms)!
# Try 36 success (now 1768 atoms)!
# Try 38 success (now 1772 atoms)!
# Try 40 success (now 1776 atoms)!
# Try 42 success (now 1780 atoms)!
# Try 43 success (now 1784 atoms)!
# Try 48 success (now 1788 atoms)!
# Try 53 success (now 1792 atoms)!
# Try 55 success (now 1796 atoms)!
# Try 57 success (now 1800 atoms)!
# Try 59 success (now 1804 atoms)!
# Try 65 success (now 1808 atoms)!
# Try 67 success (now 1812 atoms)!
# Try 77 success (now 1816 atoms)!
# Try 85 success (now 1820 atoms)!
# Try 90 success (now 1824 atoms)!
# Try 94 success (now 1828 atoms)!
# Try 100 success (now 1832 atoms)!
# Try 101 success (now 1836 atoms)!
# Try 103 success (now 1840 atoms)!
# Try 107 success (now 1844 atoms)!
# Try 112 success (now 1848 atoms)!
# Try 116 success (now 1852 atoms)!
# Try 126 success (now 1856 atoms)!
# Try 129 success (now 1860 atoms)!
# Try 130 success (now 1864 atoms)!
# Try 140 success (now 1868 atoms)!
# Try 142 success (now 1872 atoms)!
# Try 153 success (now 1876 atoms)!
# Try 156 success (now 1880 atoms)!
# Try 175 success (now 1884 atoms)!
# Try 179 success (now 1888 atoms)!
# Try 185 success (now 1892 atoms)!
# Try 189 success (now 1896 atoms)!
# Try 194 success (now 1900 atoms)!
# Try 204 success (now 1904 atoms)!
# Try 212 success (now 1908 atoms)!
# Try 213 success (now 1912 atoms)!
# Try 216 success (now 1916 atoms)!
# Try 225 success (now 1920 atoms)!
# Try 234 success (now 1924 atoms)!
# Try 240 success (now 1928 atoms)!
# Try 246 success (now 1932 atoms)!
# Try 263 success (now 1936 atoms)!
# Try 272 success (now 1940 atoms)!
# Try 274 success (now 1944 atoms)!
# Try 277 success (now 1948 atoms)!
# Try 284 success (now 1952 atoms)!
# Try 294 success (now 1956 atoms)!
# Try 297 success (now 1960 atoms)!
# Try 302 success (now 1964 atoms)!
# Try 321 success (now 1968 atoms)!
# Try 328 success (now 1972 atoms)!
# Try 335 success (now 1976 atoms)!
# Try 339 success (now 1980 atoms)!
# Try 346 success (now 1984 atoms)!
# Try 352 success (now 1988 atoms)!
# Try 354 success (now 1992 atoms)!
# Try 358 success (now 1996 atoms)!
# Try 361 success (now 2000 atoms)!
# Try 363 success (now 2004 atoms)!
# Try 365 success (now 2008 atoms)!
# Try 368 success (now 2012 atoms)!
# Try 371 success (now 2016 atoms)!
# Try 376 success (now 2020 atoms)!
# Try 421 success (now 2024 atoms)!
# Try 422 success (now 2028 atoms)!
# Try 423 success (now 2032 atoms)!
# Try 442 success (now 2036 atoms)!
# Try 465 success (now 2040 atoms)!
# Try 508 success (now 2044 atoms)!
# Try 512 success (now 2048 atoms)!
# Try 533 success (now 2052 atoms)!
# Try 536 success (now 2056 atoms)!
# Try 539 success (now 2060 atoms)!
# Try 558 success (now 2064 atoms)!
# Try 559 success (now 2068 atoms)!
# Try 576 success (now 2072 atoms)!
# Try 579 success (now 2076 atoms)!
# Try 591 success (now 2080 atoms)!
# Try 599 success (now 2084 atoms)!
# Try 607 success (now 2088 atoms)!
# Try 624 success (now 2092 atoms)!
# Try 629 success (now 2096 atoms)!
# Try 669 success (now 2100 atoms)!
# Try 681 success (now 2104 atoms)!
# Try 693 success (now 2108 atoms)!
# Try 714 success (now 2112 atoms)!
# Try 741 success (now 2116 atoms)!
# Try 755 success (now 2120 atoms)!
# Try 772 success (now 2124 atoms)!
# Try 775 success (now 2128 atoms)!
# Try 855 success (now 2132 atoms)!
# Try 935 success (now 2136 atoms)!
# Try 990 success (now 2140 atoms)!
# Try 1017 success (now 2144 atoms)!
# Try 1020 success (now 2148 atoms)!
# Try 1040 success (now 2152 atoms)!
# Try 1076 success (now 2156 atoms)!
# Try 1133 success (now 2160 atoms)!
# Try 1154 success (now 2164 atoms)!
# Try 1161 success (now 2168 atoms)!
# Try 1201 success (now 2172 atoms)!
# Try 1236 success (now 2176 atoms)!
# Try 1258 success (now 2180 atoms)!
# Try 1298 success (now 2184 atoms)!
# Try 1342 success (now 2188 atoms)!
# Try 1385 success (now 2192 atoms)!
# Try 1389 success (now 2196 atoms)!
# Try 1402 success (now 2200 atoms)!
# Try 1429 success (now 2204 atoms)!
# Try 1447 success (now 2208 atoms)!
# Try 1481 success (now 2212 atoms)!
# Try 1482 success (now 2216 atoms)!
# Try 1517 success (now 2220 atoms)!
# Try 1537 success (now 2224 atoms)!
# Try 1580 success (now 2228 atoms)!
# Try 1591 success (now 2232 atoms)!
# Try 1676 success (now 2236 atoms)!
# Try 1679 success (now 2240 atoms)!
# Try 1711 success (now 2244 atoms)!
# Try 1716 success (now 2248 atoms)!
# Try 1733 success (now 2252 atoms)!
# Try 1742 success (now 2256 atoms)!
# Try 1815 success (now 2260 atoms)!
# Try 1939 success (now 2264 atoms)!
# Try 1949 success (now 2268 atoms)!
# Try 2005 success (now 2272 atoms)!
# Try 2007 success (now 2276 atoms)!
# Try 2010 success (now 2280 atoms)!
# Try 2138 success (now 2284 atoms)!
# Try 2161 success (now 2288 atoms)!
# Try 2171 success (now 2292 atoms)!
# Try 2251 success (now 2296 atoms)!
# Try 2303 success (now 2300 atoms)!
# Try 2434 success (now 2304 atoms)!
# Try 2449 success (now 2308 atoms)!
# Try 2458 success (now 2312 atoms)!
# Try 2533 success (now 2316 atoms)!
# Try 2652 success (now 2320 atoms)!
# Try 2653 success (now 2324 atoms)!
# Try 2654 success (now 2328 atoms)!
# Try 2764 success (now 2332 atoms)!
# Try 2818 success (now 2336 atoms)!
# Try 2836 success (now 2340 atoms)!
# Try 3150 success (now 2344 atoms)!
# Try 3231 success (now 2348 atoms)!
# Try 3259 success (now 2352 atoms)!
# Try 3265 success (now 2356 atoms)!
# Try 3343 success (now 2360 atoms)!
# Try 3619 success (now 2364 atoms)!
# Try 3667 success (now 2368 atoms)!
# Try 3796 success (now 2372 atoms)!
# Try 3897 success (now 2376 atoms)!
# Try 4035 success (now 2380 atoms)!
# Try 4162 success (now 2384 atoms)!
# Try 4192 success (now 2388 atoms)!
# Try 4246 success (now 2392 atoms)!
# Try 4249 success (now 2396 atoms)!
# Try 4256 success (now 2400 atoms)!
# Try 4310 success (now 2404 atoms)!
# Try 4435 success (now 2408 atoms)!
# Try 4523 success (now 2412 atoms)!
# Try 5130 success (now 2416 atoms)!
# Try 5255 success (now 2420 atoms)!
# Try 5356 success (now 2424 atoms)!
# Try 5644 success (now 2428 atoms)!
# Try 5679 success (now 2432 atoms)!
# Try 5740 success (now 2436 atoms)!
# Try 5747 success (now 2440 atoms)!
# Try 5947 success (now 2444 atoms)!
# Try 6137 success (now 2448 atoms)!
# Try 6162 success (now 2452 atoms)!
# Try 6248 success (now 2456 atoms)!
# Try 6323 success (now 2460 atoms)!
# Try 6361 success (now 2464 atoms)!
# Try 6438 success (now 2468 atoms)!
# Try 6571 success (now 2472 atoms)!
# Try 6681 success (now 2476 atoms)!
# Try 6714 success (now 2480 atoms)!
# Try 6722 success (now 2484 atoms)!
# Try 6774 success (now 2488 atoms)!
# Try 6801 success (now 2492 atoms)!
# Try 7124 success (now 2496 atoms)!
# Try 7259 success (now 2500 atoms)!
# Try 7585 success (now 2504 atoms)!
# Try 7726 success (now 2508 atoms)!
# Try 7895 success (now 2512 atoms)!
# Try 7913 success (now 2516 atoms)!
# Try 7930 success (now 2520 atoms)!
# Try 8025 success (now 2524 atoms)!
# Try 8070 success (now 2528 atoms)!
#
# Added 200 molecules (out of 200 requested)
# Writing generated configuration to d2o_solvated.gro
#
# Back Off! I just backed up d2o_solvated.gro to ./#d2o_solvated.gro.1#
#
# Output configuration contains 2528 atoms in 632 residues
#
# GROMACS reminds you: "I've basically become a vegetarian since the only meat I'm eating is from animals I've killed myself" (Mark Zuckerberg)

# %%
# View the system
view = ng.show_structure_file("d2o_solvated.gro")
view.add_representation(repr_type='ball+stick', selection='ICE')
view.camera='orthographic'
view
# Out:
# NGLWidget()

# %%
filename = "topol.top"
molecule_name = "D2O_flex" 
correct_count = 632         # 2528 atoms / 4 atoms per molecule

with open(filename, 'r') as f:
    lines = f.readlines()

new_lines = []
found_molecules_section = False

for line in lines:
    if "[ molecules ]" in line:
        found_molecules_section = True
        new_lines.append(line)
        # Add the comment line that usually follows
        new_lines.append("; Compound        #mols\n")
        break # Stop reading the old file here
    new_lines.append(line)

# 2. Append the correct count if we found the section
if found_molecules_section:
    new_lines.append(f"{molecule_name:<15} {correct_count}\n")
    
    with open(filename, 'w') as f:
        f.writelines(new_lines)
    print(f"FIXED: topol.top now lists {correct_count} molecules of {molecule_name}.")
else:
    print("ERROR: Could not find '[ molecules ]' section in topol.top")
# Out:
# topol.top has been updated.

# %%
import os

input_gro = "d2o_solvated.gro"
output_gro = "d2o_clean.gro"
topology_file = "topol.top"
molecule_name = "D2O_flex"

# 1. (Remove MW atoms)
print(f"[STATUS] Cleaning {input_gro} to match 3-site flexible topology...")
with open(input_gro, 'r') as f:
    lines = f.readlines()

header = lines[0]
box_line = lines[-1]
atom_lines = lines[2:-1] 

new_atom_lines = []
for line in atom_lines:
    if "MW" not in line:
        new_atom_lines.append(line)

# Calculate new counts
total_atoms = len(new_atom_lines)
num_molecules = total_atoms // 3 

with open(output_gro, 'w') as f:
    f.write(header)
    f.write(f"{total_atoms:>5}\n") # Update the count header (formatted)
    f.writelines(new_atom_lines)
    f.write(box_line)

print(f"'{output_gro}' with {total_atoms} atoms (removed MWs).")
print(f" Calculated Molecule Count: {num_molecules}")


print(f"Updating {topology_file}...")

with open(topology_file, 'r') as f:
    top_lines = f.readlines()

new_top_lines = []
found_molecules = False

for line in top_lines:
    if "[molecules]" in line:
        found_molecules = True
        new_top_lines.append(line)
        new_top_lines.append("; Compound        #mols\n")
        # We stop adding old lines here to avoid duplicates
        break 
    new_top_lines.append(line)

if found_molecules:
    new_top_lines.append(f"{molecule_name:<15} {num_molecules}\n")
    
    with open(topology_file, 'w') as f:
        f.writelines(new_top_lines)
    print(f"Topology updated: {molecule_name} = {num_molecules}")
else:
    print("Could not find [ molecules ] section in topology.")
# Out:
# [STATUS] Cleaning d2o_solvated.gro to match 3-site flexible topology...
# 'd2o_clean.gro' with 1896 atoms (removed MWs).
#  Calculated Molecule Count: 632
# Updating topol.top...
# Topology updated: D2O_flex = 632

# %%
#Energy Minimization
# !gmx grompp -f em.mdp -c d2o_clean.gro -p topol.top -o em.tpr
# !gmx mdrun -deffnm em -ntmpi 1 -ntomp 1
# Out:
#                  :-) GROMACS - gmx grompp, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx grompp -f em.mdp -c d2o_clean.gro -p topol.top -o em.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
#
# NOTE 1 [file em.mdp]:
#   With Verlet lists the optimal nstlist is >= 10, with GPUs >= 20. Note
#   that with the Verlet scheme, nstlist has no effect on the accuracy of
#   your simulation.
#
# Setting the LD random seed to -218431617
#
# Generated 3 of the 3 non-bonded parameter combinations
#
# Excluding 2 bonded neighbours molecule type 'D2O_flex'
# Analysing residue names:
# There are:   632      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group rest is 5685.00
# The integrator does not provide a ensemble temperature, there is no system ensemble temperature
#
# The largest distance between excluded atoms is 0.152 nm between atom 1004 and 1005
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 24x24x24, spacing 0.117 0.117 0.117
#
# Estimate for the relative computational load of the PME mesh part: 0.23
#
# This run will generate roughly 3 Mb of data
#
# There was 1 NOTE
#
# GROMACS reminds you: "You Can Be Too Early, You Can Be Too Late and You Can Be On Time" (J. Cruijff)
#
#                   :-) GROMACS - gmx mdrun, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx mdrun -deffnm em -ntmpi 1 -ntomp 1
#
# Reading file em.tpr, VERSION 2025.4-Homebrew (single precision)
# Using 1 MPI thread
# Using 1 OpenMP thread
#
#
# Steepest Descents:
#    Tolerance (Fmax)   =  1.00000e+00
#    Number of steps    =        50000
#
# Energy minimization has stopped, but the forces have not converged to the
# requested precision Fmax < 1 (which may not be possible for your system). It
# stopped because the algorithm tried to make a new step whose size was too
# small, or there was no change in the energy since last step. Either way, we
# regard the minimization as converged to within the available machine
# precision, given your starting configuration and EM parameters.
#
# Double precision normally gives you higher accuracy, but this is often not
# needed for preparing to run molecular dynamics.
#
# writing lowest energy coordinates.
#
# Steepest Descents converged to machine precision in 8069 steps,
# but did not reach the requested Fmax < 1.
# Potential Energy  = -3.8185023e+04
# Maximum force     =  3.0485353e+01 on atom 1189
# Norm of force     =  3.1547871e+00
#
# GROMACS reminds you: "Never replicate a successful experiment." (Fett's law.)

# %%
#Analyze results of EM
# !printf "Potential\n0\n" | gmx energy -f em.edr -o potential.xvg -xvg none
# Out:
#                  :-) GROMACS - gmx energy, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx energy -f em.edr -o potential.xvg -xvg none
#
# Opened em.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  LJ-(SR)          4  Disper.-corr.
#   5  Coulomb-(SR)     6  Coul.-recip.     7  Potential        8  Pres.-DC
#   9  Pressure        10  Vir-XX          11  Vir-XY          12  Vir-XZ
#  13  Vir-YX          14  Vir-YY          15  Vir-YZ          16  Vir-ZX
#  17  Vir-ZY          18  Vir-ZZ          19  Pres-XX         20  Pres-XY
#  21  Pres-XZ         22  Pres-YX         23  Pres-YY         24  Pres-YZ
#  25  Pres-ZX         26  Pres-ZY         27  Pres-ZZ         28  #Surf*SurfTen
#  29  T-rest
#
# Last energy frame read 6377 time 8063.000
#
# Statistics over 8064 steps [ 0.0000 through 8063.0000 ps ], 1 data sets
# All statistics are over 6378 points (frames)
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Potential                  -37269.4        530    1467.33   -3402.97  (kJ/mol)
#
# GROMACS reminds you: "No, no, you're not thinking, you're just being logical." (Niels Bohr)

# %%
# Print graph
df = pd.read_csv('potential.xvg', sep='\\s+', header=None, names=['step','energy'])
df.plot('step')
# Out:
# <Axes: xlabel='step'>

# %%
# Temperature EQ T=94K
# !gmx grompp -f nvt.mdp -c em.gro -r em.gro -p topol.top -o nvt.tpr 
# !gmx mdrun -ntmpi 1 -ntomp 6 -v -deffnm nvt
# Out:
#                  :-) GROMACS - gmx grompp, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx grompp -f nvt.mdp -c em.gro -r em.gro -p topol.top -o nvt.tpr
#
# Ignoring obsolete mdp entry 'ns_type'
# Setting the LD random seed to -1749293057
#
# Generated 3 of the 3 non-bonded parameter combinations
#
# Excluding 2 bonded neighbours molecule type 'D2O_flex'
#
# Setting gen_seed to -1085440131
#
# Velocities were taken from a Maxwell distribution at 94 K
# Analysing residue names:
# There are:   632      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group System is 5685.00
#
# The largest distance between excluded atoms is 0.168 nm between atom 1190 and 1191
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 94 K
#
# Calculated rlist for 1x1 atom pair-list as 1.000 nm, buffer size 0.000 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 20x20x20, spacing 0.140 0.140 0.140
#
# Estimate for the relative computational load of the PME mesh part: 0.20
#
# This run will generate roughly 60 Mb of data
#
# GROMACS reminds you: "Have a Nice Day" (R. McDonald)
#
#                   :-) GROMACS - gmx mdrun, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx mdrun -ntmpi 1 -ntomp 6 -v -deffnm nvt
#
# Reading file nvt.tpr, VERSION 2025.4-Homebrew (single precision)
# Changing nstlist from 10 to 100, rlist from 1 to 1
#
# Using 1 MPI thread
# Using 6 OpenMP threads
#
# starting mdrun 'Flexible D2O Ice for DoS Calculations at Titan Conditions'
# 1000000 steps,    100.0 ps.
# step 999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 1000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     6111.510     1018.585      600.0
#                  (ns/day)    (hour/ns)
# Performance:        8.482        2.829
#
# GROMACS reminds you: "It's Not Dark Yet, But It's Getting There" (Bob Dylan)

# %%
# Analyze Temp run
# !echo "Temperature" | gmx energy -f nvt.edr -o temperature.xvg -xvg none -b 20
# Out:
#                  :-) GROMACS - gmx energy, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx energy -f nvt.edr -o temperature.xvg -xvg none -b 20
#
# Opened nvt.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  LJ-(SR)          4  Disper.-corr.
#   5  Coulomb-(SR)     6  Coul.-recip.     7  Potential        8  Kinetic-En.
#   9  Total-Energy    10  Conserved-En.   11  Temperature     12  Pres.-DC
#  13  Pressure        14  Vir-XX          15  Vir-XY          16  Vir-XZ
#  17  Vir-YX          18  Vir-YY          19  Vir-YZ          20  Vir-ZX
#  21  Vir-ZY          22  Vir-ZZ          23  Pres-XX         24  Pres-XY
#  25  Pres-XZ         26  Pres-YX         27  Pres-YY         28  Pres-YZ
#  29  Pres-ZX         30  Pres-ZY         31  Pres-ZZ         32  #Surf*SurfTen
#  33  T-System        34  Lamb-System
#
# Last energy frame read 10000 time  100.000
#
# Statistics over 800001 steps [ 20.0000 through 100.0000 ps ], 1 data sets
# All statistics are over 8001 points (frames)
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Temperature                 93.9571      0.051    1.77327 -0.0312748  (K)
#
# GROMACS reminds you: "As always in life, people want a simple answer... and it's always wrong." (Marie Daly)

# %%
# Plot Temp data
df = pd.read_csv('temperature.xvg', sep='\\s+', header=None, names=['time','temperature'])
df.plot('time')
#!echo "Temperature" | gmx energy -f nvt.edr -o temperature.xvg -b 20
#!xmgrace temperature.xvg
# Out:
# <Axes: xlabel='time'>

# %%
# Pressure EQ P = 1.5 bars
# !gmx grompp -f npt1.mdp -c nvt.gro -r nvt.gro -t nvt.cpt -p topol.top -o npt1.tpr -maxwarn 1
# !gmx mdrun -ntmpi 1 -ntomp 13 -v -deffnm npt1
# Out:
#                  :-) GROMACS - gmx grompp, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx grompp -f npt1.mdp -c nvt.gro -r nvt.gro -t nvt.cpt -p topol.top -o npt1.tpr -maxwarn 1
#
# Ignoring obsolete mdp entry 'ns_type'
#
# WARNING 1 [file npt1.mdp]:
#   The Berendsen barostat does not generate any strictly correct ensemble,
#   and should not be used for new production simulations (in our opinion).
#   We recommend using the C-rescale barostat instead.
#
# Setting the LD random seed to -282333186
#
# Generated 3 of the 3 non-bonded parameter combinations
#
# Excluding 2 bonded neighbours molecule type 'D2O_flex'
#
# Taking velocities from 'nvt.gro'
# Analysing residue names:
# There are:   632      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group System is 5685.00
#
# The largest distance between excluded atoms is 0.173 nm between atom 662 and 663
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 94 K
#
# Calculated rlist for 1x1 atom pair-list as 1.000 nm, buffer size 0.000 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
#
# Reading Coordinates, Velocities and Box size from old trajectory
#
# Will read whole trajectory
# Last frame         -1 time  100.000
#
# Using frame at t = 100 ps
#
# Starting time for run is 0 ps
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 24x24x24, spacing 0.117 0.117 0.117
#
# Estimate for the relative computational load of the PME mesh part: 0.23
#
# This run will generate roughly 23 Mb of data
#
# There was 1 WARNING
#
# Back Off! I just backed up npt1.tpr to ./#npt1.tpr.1#
#
# GROMACS reminds you: "No One Could Foresee the End That Came So Fast" (Slayer)
#
#                   :-) GROMACS - gmx mdrun, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx mdrun -ntmpi 1 -ntomp 13 -v -deffnm npt1
#
#
# Back Off! I just backed up npt1.log to ./#npt1.log.1#
# Reading file npt1.tpr, VERSION 2025.4-Homebrew (single precision)
# Changing nstlist from 10 to 100, rlist from 1 to 1.005
#
# Using 1 MPI thread
# Using 13 OpenMP threads
#
#
# WARNING: Oversubscribing the recommended max load of 8 logical CPUs with 13 threads.
#          This will cause considerable performance loss.
#
# Back Off! I just backed up npt1.xtc to ./#npt1.xtc.1#
#
# Back Off! I just backed up npt1.trr to ./#npt1.trr.1#
#
# Back Off! I just backed up npt1.edr to ./#npt1.edr.1#
# starting mdrun 'Flexible D2O Ice for DoS Calculations at Titan Conditions'
# 1000000 steps,    500.0 ps.
# step 999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 1000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:    20348.148     1565.242     1300.0
#                  (ns/day)    (hour/ns)
# Performance:       27.600        0.870
#
# GROMACS reminds you: "It seems likely that significant software contributions to existing scientific software projects are not likely to be rewarded through the traditional reputation economy of science. Together these factors provide a reason to expect the over-production of independent scientific software packages, and the underproduction of collaborative projects in which later academics build on the work of earlier ones." (Howison & Herbsleb)

# %%
# Analyze Pressure Data
# !echo "Pressure" | gmx energy -f npt1.edr -o pressure.xvg -xvg none
# Out:
#                  :-) GROMACS - gmx energy, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx energy -f npt1.edr -o pressure.xvg -xvg none
#
# Opened npt1.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  LJ-(SR)          4  Disper.-corr.
#   5  Coulomb-(SR)     6  Coul.-recip.     7  Potential        8  Kinetic-En.
#   9  Total-Energy    10  Conserved-En.   11  Temperature     12  Pres.-DC
#  13  Pressure        14  Box-X           15  Box-Y           16  Box-Z
#  17  Volume          18  Density         19  pV              20  Enthalpy
#  21  Vir-XX          22  Vir-XY          23  Vir-XZ          24  Vir-YX
#  25  Vir-YY          26  Vir-YZ          27  Vir-ZX          28  Vir-ZY
#  29  Vir-ZZ          30  Pres-XX         31  Pres-XY         32  Pres-XZ
#  33  Pres-YX         34  Pres-YY         35  Pres-YZ         36  Pres-ZX
#  37  Pres-ZY         38  Pres-ZZ         39  #Surf*SurfTen   40  T-System
#  41  Lamb-System
#
# Last energy frame read 2000 time  500.000
#
# Statistics over 1000001 steps [ 0.0000 through 500.0000 ps ], 1 data sets
# All statistics are over 10001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                   -292.539        230    810.524    1372.92  (bar)
#
# GROMACS reminds you: "Rub It Right Across Your Eyes" (F. Zappa)

# %%
df = pd.read_csv('pressure.xvg', sep='\\s+', header=None, names=['time','pressure'])
df.plot('time')
# Out:
# <Axes: xlabel='time'>

# %%
#!echo "Pressure" | gmx energy -f npt.edr -o pressure.xvg
#!xmgrace pressure.xvg
# Out:
#                  :-) GROMACS - gmx energy, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx energy -f npt.edr -o pressure.xvg
#
#
# -------------------------------------------------------
# Program:     gmx energy, version 2025.4-Homebrew
# Source file: src/gromacs/commandline/cmdlineparser.cpp (line 271)
# Function:    void gmx::CommandLineParser::parse(int*, char**)
#
# Error in user input:
# Invalid command-line options
#   In command-line option -f
#     File 'npt.edr' does not exist or is not accessible.
#     The file could not be opened.
#       Reason: No such file or directory
#       (call to fopen() returned error code 2)
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at https://manual.gromacs.org/current/user-guide/run-time-errors.html
# -------------------------------------------------------
# zsh:1: command not found: xmgrace

# %%
# Look at density of system
# !echo "Density" | gmx energy -f npt1.edr -o density1.xvg -xvg none
# Out:
#                  :-) GROMACS - gmx energy, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx energy -f npt1.edr -o density1.xvg -xvg none
#
# Opened npt1.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  LJ-(SR)          4  Disper.-corr.
#   5  Coulomb-(SR)     6  Coul.-recip.     7  Potential        8  Kinetic-En.
#   9  Total-Energy    10  Conserved-En.   11  Temperature     12  Pres.-DC
#  13  Pressure        14  Box-X           15  Box-Y           16  Box-Z
#  17  Volume          18  Density         19  pV              20  Enthalpy
#  21  Vir-XX          22  Vir-XY          23  Vir-XZ          24  Vir-YX
#  25  Vir-YY          26  Vir-YZ          27  Vir-ZX          28  Vir-ZY
#  29  Vir-ZZ          30  Pres-XX         31  Pres-XY         32  Pres-XZ
#  33  Pres-YX         34  Pres-YY         35  Pres-YZ         36  Pres-ZX
#  37  Pres-ZY         38  Pres-ZZ         39  #Surf*SurfTen   40  T-System
#  41  Lamb-System
#
# Last energy frame read 2000 time  500.000
#
# Statistics over 1000001 steps [ 0.0000 through 500.0000 ps ], 1 data sets
# All statistics are over 10001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Density                     1091.59         13    29.9886    79.6515  (kg/m^3)
#
# GROMACS reminds you: "A protein is a chain of letters." (Julie Bernauer)

# %%
#Plot density
df = pd.read_csv('density1.xvg', sep='\\s+', header=None, names=['time','density'])
df.plot('time')
# Out:
# <Axes: xlabel='time'>

# %%
# !tail -1 npt1.gro
# Out:
#    2.66604   2.66604   2.66604

# %%
#!gmx editconf -f npt1.gro -o npt1_expanded.gro -box 2.2 2.2 2.2 -c

# %%
# Pressure EQ Stage 2
# !gmx grompp -f npt1.mdp -c npt1.gro -p topol.top -o npt2.tpr -maxwarn 1
# !gmx mdrun -ntmpi 1 -ntomp 6 -v -deffnm npt2
# Out:
#                  :-) GROMACS - gmx grompp, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx grompp -f npt1.mdp -c npt1.gro -p topol.top -o npt2.tpr -maxwarn 1
#
# Ignoring obsolete mdp entry 'ns_type'
#
# WARNING 1 [file npt1.mdp]:
#   The Berendsen barostat does not generate any strictly correct ensemble,
#   and should not be used for new production simulations (in our opinion).
#   We recommend using the C-rescale barostat instead.
#
# Setting the LD random seed to 2110431583
#
# Generated 3 of the 3 non-bonded parameter combinations
#
# Excluding 2 bonded neighbours molecule type 'D2O_flex'
#
# Taking velocities from 'npt1.gro'
# Analysing residue names:
# There are:   632      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group System is 5685.00
#
# The largest distance between excluded atoms is 0.175 nm between atom 482 and 483
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 94 K
#
# Calculated rlist for 1x1 atom pair-list as 1.001 nm, buffer size 0.001 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.000 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 24x24x24, spacing 0.111 0.111 0.111
#
# Estimate for the relative computational load of the PME mesh part: 0.21
#
# This run will generate roughly 23 Mb of data
#
# There was 1 WARNING
#
# GROMACS reminds you: "Be less curious about people and more curious about ideas." (Marie Curie)
#
#                   :-) GROMACS - gmx mdrun, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx mdrun -ntmpi 1 -ntomp 6 -v -deffnm npt2
#
# Reading file npt2.tpr, VERSION 2025.4-Homebrew (single precision)
# Changing nstlist from 10 to 100, rlist from 1 to 1.006
#
# Using 1 MPI thread
# Using 6 OpenMP threads
#
# starting mdrun 'Flexible D2O Ice for DoS Calculations at Titan Conditions'
# 1000000 steps,    500.0 ps.
# step 999900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 1000000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:     9158.388     1526.398      600.0
#                  (ns/day)    (hour/ns)
# Performance:       28.302        0.848
#
# GROMACS reminds you: "I have no responsibility to live up to what others expect of me. That's their mistake, not my failing." (Richard Feynman)

# %%
# Analyze Pressure Data
# !echo "Pressure" | gmx energy -f npt2.edr -o pressure2.xvg -xvg none

df = pd.read_csv('pressure2.xvg', sep='\\s+', header=None, names=['time','pressure'])
df.plot('time')
# Out:
#                  :-) GROMACS - gmx energy, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx energy -f npt2.edr -o pressure2.xvg -xvg none
#
# Opened npt2.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  LJ-(SR)          4  Disper.-corr.
#   5  Coulomb-(SR)     6  Coul.-recip.     7  Potential        8  Kinetic-En.
#   9  Total-Energy    10  Conserved-En.   11  Temperature     12  Pres.-DC
#  13  Pressure        14  Box-X           15  Box-Y           16  Box-Z
#  17  Volume          18  Density         19  pV              20  Enthalpy
#  21  Vir-XX          22  Vir-XY          23  Vir-XZ          24  Vir-YX
#  25  Vir-YY          26  Vir-YZ          27  Vir-ZX          28  Vir-ZY
#  29  Vir-ZZ          30  Pres-XX         31  Pres-XY         32  Pres-XZ
#  33  Pres-YX         34  Pres-YY         35  Pres-YZ         36  Pres-ZX
#  37  Pres-ZY         38  Pres-ZZ         39  #Surf*SurfTen   40  T-System
#  41  Lamb-System
#
# Last energy frame read 2000 time  500.000
#
# Statistics over 1000001 steps [ 0.0000 through 500.0000 ps ], 1 data sets
# All statistics are over 10001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Pressure                   -12.1506        9.6    489.129   -31.0282  (bar)
#
# GROMACS reminds you: "All Work and No Play Makes Jack a Dull Boy" (The Shining)
# <Axes: xlabel='time'>

# %%
# Look at density of system
# !echo "Density" | gmx energy -f npt2.edr -o density2.xvg -xvg none

#Plot density
df = pd.read_csv('density2.xvg', sep='\\s+', header=None, names=['time','density'])
df.plot('time')
# Out:
#                  :-) GROMACS - gmx energy, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx energy -f npt2.edr -o density2.xvg -xvg none
#
# Opened npt2.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  Bond             2  Angle            3  LJ-(SR)          4  Disper.-corr.
#   5  Coulomb-(SR)     6  Coul.-recip.     7  Potential        8  Kinetic-En.
#   9  Total-Energy    10  Conserved-En.   11  Temperature     12  Pres.-DC
#  13  Pressure        14  Box-X           15  Box-Y           16  Box-Z
#  17  Volume          18  Density         19  pV              20  Enthalpy
#  21  Vir-XX          22  Vir-XY          23  Vir-XZ          24  Vir-YX
#  25  Vir-YY          26  Vir-YZ          27  Vir-ZX          28  Vir-ZY
#  29  Vir-ZZ          30  Pres-XX         31  Pres-XY         32  Pres-XZ
#  33  Pres-YX         34  Pres-YY         35  Pres-YZ         36  Pres-ZX
#  37  Pres-ZY         38  Pres-ZZ         39  #Surf*SurfTen   40  T-System
#  41  Lamb-System
#
# Last energy frame read 2000 time  500.000
#
# Statistics over 1000001 steps [ 0.0000 through 500.0000 ps ], 1 data sets
# All statistics are over 10001 points
#
# Energy                      Average   Err.Est.       RMSD  Tot-Drift
# -------------------------------------------------------------------------------
# Density                     1111.51        1.4    3.07017     9.5322  (kg/m^3)
#
# GROMACS reminds you: "Why Weren't You at My Funeral ?" (G. Groenhof)
# <Axes: xlabel='time'>

# %%
# A. Generate the new run file
# !gmx grompp -f d2o_production.mdp -c npt2.gro -p topol.top -o md_dos_fixed.tpr

# B. Run the short 20ps simulation (should take ~1 min)
# !gmx mdrun -deffnm md_dos_fixed -v

# C. Calculate the VDOS
# !echo "System" | gmx dos -f md_dos_fixed.trr -s md_dos_fixed.tpr -dos dos_fixed.xvg
# Out:
#                  :-) GROMACS - gmx grompp, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx grompp -f d2o_production.mdp -c npt2.gro -p topol.top -o md_dos_fixed.tpr
#
# Setting the LD random seed to -1762152483
#
# Generated 3 of the 3 non-bonded parameter combinations
#
# Excluding 2 bonded neighbours molecule type 'D2O_flex'
#
# Taking velocities from 'npt2.gro'
# Analysing residue names:
# There are:   632      Other residues
# Analysing residues not classified as Protein/DNA/RNA/Water and splitting into groups...
# Number of degrees of freedom in T-Coupling group System is 5685.00
#
# The largest distance between excluded atoms is 0.174 nm between atom 1160 and 1161
#
# Determining Verlet buffer for a tolerance of 0.005 kJ/mol/ps at 94 K
#
# Calculated rlist for 1x1 atom pair-list as 1.052 nm, buffer size 0.002 nm
#
# Set rlist, assuming 4x4 atom pair-list, to 1.050 nm, buffer size 0.000 nm
#
# Note that mdrun will redetermine rlist based on the actual pair-list setup
# Calculating fourier grid dimensions for X Y Z
# Using a fourier grid of 24x24x24, spacing 0.111 0.111 0.111
#
# Estimate for the relative computational load of the PME mesh part: 0.19
#
# This run will generate roughly 868 Mb of data
#
# GROMACS reminds you: "It is unfortunate that the authors did not make better use of all the electric power energy that went into these massive computations." (An anonymous referee)
#
#                   :-) GROMACS - gmx mdrun, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx mdrun -deffnm md_dos_fixed -v
#
# Reading file md_dos_fixed.tpr, VERSION 2025.4-Homebrew (single precision)
# Changing nstlist from 20 to 100, rlist from 1.05 to 1.055
#
# Using 1 MPI thread
# Using 8 OpenMP threads
#
# starting mdrun 'Flexible D2O Ice for DoS Calculations at Titan Conditions'
# 40000 steps,     20.0 ps.
# step 39900, remaining wall clock time:     0 s
# Writing final coordinates.
# step 40000, remaining wall clock time:     0 s
#                Core t (s)   Wall t (s)        (%)
#        Time:      465.725       58.216      800.0
#                  (ns/day)    (hour/ns)
# Performance:       29.683        0.809
#
# GROMACS reminds you: "Been There, Done It" (Beavis and Butthead)
#
#                    :-) GROMACS - gmx dos, 2025.4-Homebrew (-:
#
# Executable:   /opt/homebrew/bin/../Cellar/gromacs/2025.4/bin/gmx
# Data prefix:  /opt/homebrew/bin/../Cellar/gromacs/2025.4
# Working dir:  /Users/mackenziehenley/cp2k/D2O_ice/GroMACK
# Command line:
#   gmx dos -f md_dos_fixed.trr -s md_dos_fixed.tpr -dos dos_fixed.xvg
#
#
# Back Off! I just backed up dos.log to ./#dos.log.1#
# Reading file md_dos_fixed.tpr, VERSION 2025.4-Homebrew (single precision)
# Reading file md_dos_fixed.tpr, VERSION 2025.4-Homebrew (single precision)
# Group     0 (         System) has  1896 elements
# Group     1 (          Other) has  1896 elements
# Group     2 (            ICE) has  1896 elements
# Select a group: Selected 0: 'System'
# trr version: GMX_trn_file (single precision)
# Last frame      40000 time   20.000
# Going to do 5688 fourier transforms of length 40001. Hang on.
# Average correlation time 0.000 Std. Dev. 0.000 Error 0.000 (ps)
# Going to merge the ACFs into the mass-weighted and plain ACF
#
# Back Off! I just backed up vacf.xvg to ./#vacf.xvg.1#
#
# Back Off! I just backed up mvacf.xvg to ./#mvacf.xvg.1#
#
# GROMACS reminds you: "If at one time or another I have brushed a few colleagues the wrong way, I must apologize: I had not realized that they were covered with fur." (Edwin Chargaff)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. Load the data 
# We don't name columns yet to prevent alignment errors
df_dos = pd.read_csv(
    'dos_fixed.xvg', 
    sep=r'\s+', 
    comment='@', 
    header=None,
    on_bad_lines='skip',
    engine='python'
)

# 2. Convert everything to numeric (turning stray text into NaN)
df_dos = df_dos.apply(pd.to_numeric, errors='coerce')

# 3. Drop rows that are completely NaN (usually empty lines at end of file)
df_dos = df_dos.dropna(how='all')

df_dos = df_dos.iloc[:, :2] 
df_dos.columns = ['freq', 'dos']

# 5. Convert Frequency (ps^-1) to Wavenumber (cm^-1)
# Conversion factor: 1 ps^-1 = 33.35641 cm^-1
df_dos['freq_cm'] = df_dos['freq'] * 33.35641

# 6. Create the plot
plt.figure(figsize=(10, 6))

if not df_dos.empty:
    plt.plot(df_dos['freq_cm'], df_dos['dos'], color='navy', linewidth=1.5, label='D₂O Ice (94 K)')
    
    # --- Highlight Physics Regions for D2O ---
    # Lattice / Translation (< 350)
    plt.axvspan(0, 350, color='blue', alpha=0.1)
    plt.text(175, df_dos['dos'].max()*0.8, "Lattice", color='blue', ha='center')

    # Libration (350 - 1000)
    plt.axvspan(350, 1000, color='green', alpha=0.1)
    plt.text(675, df_dos['dos'].max()*0.6, "Libration", color='green', ha='center')

    # Bending (~1200)
    plt.axvspan(1100, 1300, color='orange', alpha=0.1)
    plt.text(1200, df_dos['dos'].max()*0.4, "Bending", color='darkorange', ha='center')

    # Stretching (~2300-2600)
    plt.axvspan(2300, 2600, color='red', alpha=0.1)
    plt.text(2450, df_dos['dos'].max()*0.4, "Stretching", color='red', ha='center')

    # Styling
    plt.title('Vibrational Density of States - D₂O Ice', fontsize=14)
    plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=12)
    plt.ylabel('Density of States (a.u.)', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.6)
    
    # Set X-limit to see the whole spectrum
    plt.xlim(0, 3000) 
    plt.ylim(0, df_dos['dos'].max() * 1.1)
    
    plt.legend()
    plt.tight_layout()
    plt.show()
else:
    print("The dataframe is empty.")
